# %%
Here is the cleaned-up and well-organized theoretical content (without code) about Data Selection & Filtering in Pandas for your GitHub documentation:

---

# 📊 Data Selection & Filtering in Pandas (Theory)

## Overview

Selecting the appropriate rows and columns is the first step in analyzing any dataset. Pandas provides flexible and powerful methods for this purpose.

---

## 📌 Selecting Columns

* You can retrieve single or multiple columns from a DataFrame.
* Single column selection returns a Series.
* Multiple column selection returns a DataFrame.

---

## 📌 Selecting Rows

Pandas offers two primary methods:

* `.loc[]`: Label-based indexing.
* `.iloc[]`: Position-based indexing.

You can select:

* A single row.
* A specific value by combining row and column selection.
* A range of rows and/or specific columns via slicing.

---

## ⚡ Fast Element Access

For accessing individual elements efficiently:

* `.at[]`: Label-based fast access.
* `.iat[]`: Position-based fast access.

---

## 🎯 Filtering with Conditions

### ✅ Basic Filtering

* You can filter rows based on a condition applied to a column (e.g., all rows where Age > 30).

### ✅ Multiple Conditions

* Combine conditions using:

  * `&` (AND)
  * `|` (OR)
* Always use parentheses around individual conditions.

---

## 🔍 Querying with `.query()`

A more readable, SQL-like method for filtering rows using expressions in string format.

### 📝 Key Rules:

1. Column names are treated as variables.
2. Use quotes around string values.
3. Use backticks for column names with spaces or special characters.
4. Use `@` to reference external Python variables inside the query.
5. Use logical operators: and, or, not (instead of &, |, \~).
6. Supports chained comparisons (e.g., 25 < age <= 40).
7. Avoid Python reserved keywords as column names; use backticks if necessary.
8. Case sensitivity matters for both column names and string values.
9. Returns a copy of the DataFrame — not a view.

---

## 🧠 Summary

* Use indexing methods like `df[col]`, `.loc[]`, `.iloc[]`, `.at[]`, and `.iat[]` to access data.
* Filter using logical conditions or `.query()` for cleaner, readable syntax.
* Mastering these methods makes the rest of data manipulation in pandas easier and more efficient.

---

Let me know if you'd like this in Markdown format for direct use in your GitHub README or Jupyter Notebook.
# Out:
#   Cell In[43], line 1
#     Here is the cleaned-up and well-organized theoretical content (without code) about Data Selection & Filtering in Pandas for your GitHub documentation:
#                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df = pd.read_csv("train_outliers_preprocessed.csv")

# %%
df
# Out:
#        age     sex  gender     cp  trestbps  chol  fbs  restecg  thalach  \
# 0     52.0  Female  Female  120.0     125.0   0.0  0.0    152.0      0.0
# 1     53.0       0  Female  140.0     203.0   0.0  0.0    155.0      0.0
# 2     70.0       0  Female  145.0     174.0   0.0  1.0    125.0      0.0
# 3     61.0       0  Female  148.0     203.0   0.0  1.0    161.0      0.0
# 4     62.0       0  Female  138.0     294.0   0.0  1.0    152.0      0.0
# ...    ...     ...     ...    ...       ...   ...  ...      ...      ...
# 1020  59.0       1    Male  140.0     204.0   0.0  1.0    152.0      0.0
# 1021  60.0       0  Female  120.0     204.0   0.0  1.0    152.0      0.0
# 1022  47.0       0  Female  120.0     204.0   0.0  0.0    118.0      0.0
# 1023  50.0       0  Female  120.0     204.0   0.0  0.0    159.0      0.0
# 1024  54.0       0  Female  120.0     204.0   0.0  1.0    113.0      0.0
#
#       exang  oldpeak  slope   ca  thal  target
# 0       0.0      1.0    2.0  2.0   1.0     0.0
# 1       3.1      0.0    0.0  3.0   0.0     0.0
# 2       2.6      0.0    0.0  3.0   0.0     0.0
# 3       0.0      2.0    1.0  3.0   0.0     0.0
# 4       0.0      1.0    0.0  2.0   0.0     0.0
# ...     ...      ...    ...  ...   ...     ...
# 1020    0.0      2.0    0.0  2.0   1.0     1.0
# 1021    2.8      1.0    1.0  3.0   0.0     0.0
# 1022    1.0      1.0    1.0  2.0   0.0     0.0
# 1023    0.0      2.0    0.0  2.0   1.0     1.0
# 1024    1.4      1.0    1.0  3.0   0.0     0.0
#
# [1025 rows x 15 columns]

# %%
df['sex']
# Out:
# 0       Female
# 1            0
# 2            0
# 3            0
# 4            0
#          ...
# 1020         1
# 1021         0
# 1022         0
# 1023         0
# 1024         0
# Name: sex, Length: 1025, dtype: object

# %%
type(df['sex'])
# Out:
# pandas.core.series.Series

# %%
df[['sex','gender']]
# Out:
#          sex  gender
# 0     Female  Female
# 1          0  Female
# 2          0  Female
# 3          0  Female
# 4          0  Female
# ...      ...     ...
# 1020       1    Male
# 1021       0  Female
# 1022       0  Female
# 1023       0  Female
# 1024       0  Female
#
# [1025 rows x 2 columns]

# %%
df.loc[1]
# Out:
# age           53.0
# sex              0
# gender      Female
# cp           140.0
# trestbps     203.0
# chol           0.0
# fbs            0.0
# restecg      155.0
# thalach        0.0
# exang          3.1
# oldpeak        0.0
# slope          0.0
# ca             3.0
# thal           0.0
# target         0.0
# Name: 1, dtype: object

# %%
df.loc[1,'gender']
# Out:
# 'Female'

# %%
df.loc[0:1,["gender","age"]]
# Out:
#    gender   age
# 0  Female  52.0
# 1  Female  53.0

# %%
df.at[0,'age']
# Out:
# 52.0

# %%
df.iat[0,3]#3row and coloum
# Out:
# 120.0

# %%
df[df['age']>53]['age']
# Out:
# 2       70.0
# 3       61.0
# 4       62.0
# 5       58.0
# 6       58.0
#         ...
# 1015    58.0
# 1016    65.0
# 1020    59.0
# 1021    60.0
# 1024    54.0
# Name: age, Length: 679, dtype: float64

# %%
df[(df['age']>53) & (df['gender'])]['age']
# Out:
# 2       70.0
# 3       61.0
# 4       62.0
# 5       58.0
# 6       58.0
#         ...
# 1015    58.0
# 1016    65.0
# 1020    59.0
# 1021    60.0
# 1024    54.0
# Name: age, Length: 679, dtype: float64

# %%
df.query("age > 54 and gender == 'Female'")[['age', 'gender']]
# Out:
#        age  gender
# 2     70.0  Female
# 3     61.0  Female
# 4     62.0  Female
# 5     58.0  Female
# 6     58.0  Female
# ...    ...     ...
# 1007  56.0  Female
# 1013  58.0  Female
# 1015  58.0  Female
# 1016  65.0  Female
# 1021  60.0  Female
#
# [569 rows x 2 columns]

# %%
col = "age"
df.query(f"{col} > 25")
# Out:
#        age     sex  gender     cp  trestbps  chol  fbs  restecg  thalach  \
# 0     52.0  Female  Female  120.0     125.0   0.0  0.0    152.0      0.0
# 1     53.0       0  Female  140.0     203.0   0.0  0.0    155.0      0.0
# 2     70.0       0  Female  145.0     174.0   0.0  1.0    125.0      0.0
# 3     61.0       0  Female  148.0     203.0   0.0  1.0    161.0      0.0
# 4     62.0       0  Female  138.0     294.0   0.0  1.0    152.0      0.0
# ...    ...     ...     ...    ...       ...   ...  ...      ...      ...
# 1020  59.0       1    Male  140.0     204.0   0.0  1.0    152.0      0.0
# 1021  60.0       0  Female  120.0     204.0   0.0  1.0    152.0      0.0
# 1022  47.0       0  Female  120.0     204.0   0.0  0.0    118.0      0.0
# 1023  50.0       0  Female  120.0     204.0   0.0  0.0    159.0      0.0
# 1024  54.0       0  Female  120.0     204.0   0.0  1.0    113.0      0.0
#
#       exang  oldpeak  slope   ca  thal  target
# 0       0.0      1.0    2.0  2.0   1.0     0.0
# 1       3.1      0.0    0.0  3.0   0.0     0.0
# 2       2.6      0.0    0.0  3.0   0.0     0.0
# 3       0.0      2.0    1.0  3.0   0.0     0.0
# 4       0.0      1.0    0.0  2.0   0.0     0.0
# ...     ...      ...    ...  ...   ...     ...
# 1020    0.0      2.0    0.0  2.0   1.0     1.0
# 1021    2.8      1.0    1.0  3.0   0.0     0.0
# 1022    1.0      1.0    1.0  2.0   0.0     0.0
# 1023    0.0      2.0    0.0  2.0   1.0     1.0
# 1024    1.4      1.0    1.0  3.0   0.0     0.0
#
# [1025 rows x 15 columns]

# %%
df.query("gender == 'male'")
# Out:
# Empty DataFrame
# Columns: [age, sex, gender, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
age_limit = 61
df.query("age > @age_limit")
# Out:
#        age sex  gender     cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 2     70.0   0  Female  145.0     174.0   0.0  1.0    125.0      0.0    2.6
# 4     62.0   0  Female  138.0     294.0   0.0  1.0    152.0      0.0    0.0
# 10    71.0   0  Female  112.0     149.0   0.0  1.0    125.0      0.0    1.6
# 21    67.0   0  Female  106.0     223.0   0.0  1.0    142.0      0.0    0.3
# 23    63.0   2  Female  135.0     252.0   0.0  0.0    172.0      0.0    0.0
# ...    ...  ..     ...    ...       ...   ...  ...      ...      ...    ...
# 989   71.0   1    Male  120.0     302.0   0.0  1.0    152.0      0.0    0.4
# 999   67.0   0  Female  120.0     254.0   0.0  1.0    152.0      0.0    0.2
# 1000  64.0   0  Female  120.0     212.0   0.0  0.0    152.0      0.0    2.0
# 1002  66.0   0  Female  120.0     212.0   0.0  0.0    152.0      0.0    0.1
# 1016  65.0   3  Female  138.0     282.0   0.0  0.0    152.0      0.0    1.4
#
#       oldpeak  slope   ca  thal  target
# 2         0.0    0.0  3.0   0.0     0.0
# 4         1.0    0.0  2.0   0.0     0.0
# 10        1.0    0.0  2.0   1.0     1.0
# 21        2.0    2.0  2.0   1.0     1.0
# 23        2.0    0.0  2.0   1.0     1.0
# ...       ...    ...  ...   ...     ...
# 989       2.0    2.0  2.0   1.0     1.0
# 999       1.0    2.0  3.0   0.0     0.0
# 1000      1.0    2.0  1.0   0.0     0.0
# 1002      2.0    1.0  2.0   0.0     0.0
# 1016      1.0    1.0  2.0   0.0     0.0
#
# [192 rows x 15 columns]

# %%
col = "age"
df.query(f"{col} > 25")[['age'],['gender']])
# Out:
# [['age'], ['gender']]

# %%
df.query(f"{col} > 25")[['age', 'gender']]
# Out:
#        age  gender
# 0     52.0  Female
# 1     53.0  Female
# 2     70.0  Female
# 3     61.0  Female
# 4     62.0  Female
# ...    ...     ...
# 1020  59.0    Male
# 1021  60.0  Female
# 1022  47.0  Female
# 1023  50.0  Female
# 1024  54.0  Female
#
# [1025 rows x 2 columns]

# %%
df.loc[df["age"] > 52, "gender"] = "male"

# %%
df
# Out:
#        age     sex  gender     cp  trestbps  chol  fbs  restecg  thalach  \
# 0     52.0  Female  Female  120.0     125.0   0.0  0.0    152.0      0.0
# 1     53.0       0    male  140.0     203.0   0.0  0.0    155.0      0.0
# 2     70.0       0    male  145.0     174.0   0.0  1.0    125.0      0.0
# 3     61.0       0    male  148.0     203.0   0.0  1.0    161.0      0.0
# 4     62.0       0    male  138.0     294.0   0.0  1.0    152.0      0.0
# ...    ...     ...     ...    ...       ...   ...  ...      ...      ...
# 1020  59.0       1    male  140.0     204.0   0.0  1.0    152.0      0.0
# 1021  60.0       0    male  120.0     204.0   0.0  1.0    152.0      0.0
# 1022  47.0       0  Female  120.0     204.0   0.0  0.0    118.0      0.0
# 1023  50.0       0  Female  120.0     204.0   0.0  0.0    159.0      0.0
# 1024  54.0       0    male  120.0     204.0   0.0  1.0    113.0      0.0
#
#       exang  oldpeak  slope   ca  thal  target
# 0       0.0      1.0    2.0  2.0   1.0     0.0
# 1       3.1      0.0    0.0  3.0   0.0     0.0
# 2       2.6      0.0    0.0  3.0   0.0     0.0
# 3       0.0      2.0    1.0  3.0   0.0     0.0
# 4       0.0      1.0    0.0  2.0   0.0     0.0
# ...     ...      ...    ...  ...   ...     ...
# 1020    0.0      2.0    0.0  2.0   1.0     1.0
# 1021    2.8      1.0    1.0  3.0   0.0     0.0
# 1022    1.0      1.0    1.0  2.0   0.0     0.0
# 1023    0.0      2.0    0.0  2.0   1.0     1.0
# 1024    1.4      1.0    1.0  3.0   0.0     0.0
#
# [1025 rows x 15 columns]

# %%
d2 = df.copy()

# %%
d2 = df[df["age"] > 54].copy()

# %%
df[['age', 'gender']]
# Out:
#        age  gender
# 0     52.0  Female
# 1     53.0    male
# 2     70.0    male
# 3     61.0    male
# 4     62.0    male
# ...    ...     ...
# 1020  59.0    male
# 1021  60.0    male
# 1022  47.0  Female
# 1023  50.0  Female
# 1024  54.0    male
#
# [1025 rows x 2 columns]

# %%
d2 = df[['age', 'gender']].copy()

# %%
d2
# Out:
#        age  gender
# 0     52.0  Female
# 1     53.0    male
# 2     70.0    male
# 3     61.0    male
# 4     62.0    male
# ...    ...     ...
# 1020  59.0    male
# 1021  60.0    male
# 1022  47.0  Female
# 1023  50.0  Female
# 1024  54.0    male
#
# [1025 rows x 2 columns]

# %%
d2["gender"] = "Male"

# %%
d2
# Out:
#        age gender
# 0     52.0   Male
# 1     53.0   Male
# 2     70.0   Male
# 3     61.0   Male
# 4     62.0   Male
# ...    ...    ...
# 1020  59.0   Male
# 1021  60.0   Male
# 1022  47.0   Male
# 1023  50.0   Male
# 1024  54.0   Male
#
# [1025 rows x 2 columns]

# %%
df
# Out:
#        age     sex  gender     cp  trestbps  chol  fbs  restecg  thalach  \
# 0     52.0  Female  Female  120.0     125.0   0.0  0.0    152.0      0.0
# 1     53.0       0    male  140.0     203.0   0.0  0.0    155.0      0.0
# 2     70.0       0    male  145.0     174.0   0.0  1.0    125.0      0.0
# 3     61.0       0    male  148.0     203.0   0.0  1.0    161.0      0.0
# 4     62.0       0    male  138.0     294.0   0.0  1.0    152.0      0.0
# ...    ...     ...     ...    ...       ...   ...  ...      ...      ...
# 1020  59.0       1    male  140.0     204.0   0.0  1.0    152.0      0.0
# 1021  60.0       0    male  120.0     204.0   0.0  1.0    152.0      0.0
# 1022  47.0       0  Female  120.0     204.0   0.0  0.0    118.0      0.0
# 1023  50.0       0  Female  120.0     204.0   0.0  0.0    159.0      0.0
# 1024  54.0       0    male  120.0     204.0   0.0  1.0    113.0      0.0
#
#       exang  oldpeak  slope   ca  thal  target
# 0       0.0      1.0    2.0  2.0   1.0     0.0
# 1       3.1      0.0    0.0  3.0   0.0     0.0
# 2       2.6      0.0    0.0  3.0   0.0     0.0
# 3       0.0      2.0    1.0  3.0   0.0     0.0
# 4       0.0      1.0    0.0  2.0   0.0     0.0
# ...     ...      ...    ...  ...   ...     ...
# 1020    0.0      2.0    0.0  2.0   1.0     1.0
# 1021    2.8      1.0    1.0  3.0   0.0     0.0
# 1022    1.0      1.0    1.0  2.0   0.0     0.0
# 1023    0.0      2.0    0.0  2.0   1.0     1.0
# 1024    1.4      1.0    1.0  3.0   0.0     0.0
#
# [1025 rows x 15 columns]
