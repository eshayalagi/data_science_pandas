# %% [markdown]
# --
#
# ### 🔄 Data Transformation
#
# Once your data is cleaned, the next step is to **reshape, reformat, and reorder** it as needed for further analysis. Pandas provides a wide array of flexible tools to help with this process.
#
# ---
#
# ### 🔢 Sorting & Ranking
#
# #### **Sort by Values**
#
# You can sort a DataFrame based on one or more column values. Sorting helps in arranging your data in a meaningful order, such as ascending or descending order by age or salary. When sorting by multiple columns, the DataFrame is sorted by the first column, and in the case of ties, the second column is used to break the tie.
#
# #### **Reset Index**
#
# After certain operations, the DataFrame index might become non-sequential. Resetting the index helps reassign a fresh, sequential index, optionally dropping the old one.
#
# #### **Sort by Index**
#
# When rows are identified by index values that may be unsorted, sorting by index can restore a predictable row order. This is especially useful after row deletions or concatenation.
#
# #### **Ranking**
#
# Ranking assigns a rank to numeric values in a column. The default behavior gives tied values the average rank, resulting in decimal values. Other methods like 'dense' can assign the same rank to ties while keeping the sequence without gaps. Ranking is useful for scoring, leaderboards, and comparative analysis.
#
# ---
#
# ### 🏷 Renaming Columns & Index
#
# You can rename specific columns or index values to make them more descriptive or standardized. Renaming improves the clarity of your data, especially when dealing with multiple sources or preparing data for visualization.
#
# To rename all columns at once, simply assign a new list of names that better represent the data.
#
# ---
#
# ### 📊 Changing Column Order
#
# Reordering columns helps prioritize which data to focus on. You can rearrange the entire column layout or bring specific columns (like 'Name' or 'City') to the front for better readability.
#
# ---
#
# ### ✅ Summary
#
# * Use **sorting** to organize your data by value or index.
# * Use **ranking** to understand relative positions or performance.
# * Use **renaming** to make column headers or index labels more meaningful.
# * Use **reordering** to present the most important columns first.
#
# These transformations are essential steps in **Exploratory Data Analysis ( a Markdown `.md` file for direct use in a GitHub repo?

# %%
import pandas as pd

# Create a clean sample dataset
data = {
    "Actor": [
        "Shah Rukh Khan", "Aamir Khan", "Salman Khan", "Ranbir Kapoor", "Ayushmann Khurrana",
        "Deepika Padukone", "Alia Bhatt", "Akshay Kumar", "Kangana Ranaut", "Rajkummar Rao"
    ],
    "Film": [
        "Chennai Express", "Dangal", "Bajrangi Bhaijaan", "Barfi!", "Andhadhun",
        "Padmaavat", "Raazi", "Toilet: Ek Prem Katha", "Queen", "Stree"
    ],
    "Year": [
        2013, 2016, 2015, 2012, 2018,
        2018, 2018, 2017, 2014, 2018
    ],
    "Genre": [
        "Action-Comedy", "Sports-Drama", "Drama", "Romantic-Comedy", "Thriller",
        "Historical-Drama", "Spy-Thriller", "Comedy-Drama", "Comedy-Drama", "Horror-Comedy"
    ],
    "BoxOffice (INR Crore)": [
        423, 2024, 969, 175, 456,
        585, 197, 311, 108, 180
    ],
    "IMDB": [
        6.9, 8.4, 8.1, 8.1, 8.2,
        7.0, 7.7, 7.2, 8.2, 7.5
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#                 Actor                   Film  Year             Genre  \
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
# 1          Aamir Khan                 Dangal  2016      Sports-Drama
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy
#
#    BoxOffice (INR Crore)  IMDB
# 0                    423   6.9
# 1                   2024   8.4
# 2                    969   8.1
# 3                    175   8.1
# 4                    456   8.2
# 5                    585   7.0
# 6                    197   7.7
# 7                    311   7.2
# 8                    108   8.2
# 9                    180   7.5

# %%
df.sort_values("Actor")
# Out:
#                 Actor                   Film  Year             Genre  \
# 1          Aamir Khan                 Dangal  2016      Sports-Drama
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
#
#    BoxOffice (INR Crore)  IMDB
# 1                   2024   8.4
# 7                    311   7.2
# 6                    197   7.7
# 4                    456   8.2
# 5                    585   7.0
# 8                    108   8.2
# 9                    180   7.5
# 3                    175   8.1
# 2                    969   8.1
# 0                    423   6.9

# %%
df.sort_values("Actor", ascending=False)
# Out:
#                 Actor                   Film  Year             Genre  \
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 1          Aamir Khan                 Dangal  2016      Sports-Drama
#
#    BoxOffice (INR Crore)  IMDB
# 0                    423   6.9
# 2                    969   8.1
# 3                    175   8.1
# 9                    180   7.5
# 8                    108   8.2
# 5                    585   7.0
# 4                    456   8.2
# 6                    197   7.7
# 7                    311   7.2
# 1                   2024   8.4

# %%
df.sort_values(["Actor", "IMDB"])
# Out:
#                 Actor                   Film  Year             Genre  \
# 1          Aamir Khan                 Dangal  2016      Sports-Drama
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
#
#    BoxOffice (INR Crore)  IMDB
# 1                   2024   8.4
# 7                    311   7.2
# 6                    197   7.7
# 4                    456   8.2
# 5                    585   7.0
# 8                    108   8.2
# 9                    180   7.5
# 3                    175   8.1
# 2                    969   8.1
# 0                    423   6.9

# %%
df2=df.sort_values(["Actor", "IMDB"]).copy()

# %%
df2.reset_index()
# Out:
#    index               Actor                   Film  Year             Genre  \
# 0      1          Aamir Khan                 Dangal  2016      Sports-Drama
# 1      7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 2      6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 3      4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 4      5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 5      8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 6      9       Rajkummar Rao                  Stree  2018     Horror-Comedy
# 7      3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 8      2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 9      0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
#
#    BoxOffice (INR Crore)  IMDB
# 0                   2024   8.4
# 1                    311   7.2
# 2                    197   7.7
# 3                    456   8.2
# 4                    585   7.0
# 5                    108   8.2
# 6                    180   7.5
# 7                    175   8.1
# 8                    969   8.1
# 9                    423   6.9

# %%
df.reset_index(drop=True, inplace=True) ##origional data

# %%
df
# Out:
#                 Actor                   Film  Year             Genre  \
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
# 1          Aamir Khan                 Dangal  2016      Sports-Drama
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy
#
#    BoxOffice (INR Crore)  IMDB
# 0                    423   6.9
# 1                   2024   8.4
# 2                    969   8.1
# 3                    175   8.1
# 4                    456   8.2
# 5                    585   7.0
# 6                    197   7.7
# 7                    311   7.2
# 8                    108   8.2
# 9                    180   7.5

# %%
df2
# Out:
#                 Actor                   Film  Year             Genre  \
# 1          Aamir Khan                 Dangal  2016      Sports-Drama
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
#
#    BoxOffice (INR Crore)  IMDB
# 1                   2024   8.4
# 7                    311   7.2
# 6                    197   7.7
# 4                    456   8.2
# 5                    585   7.0
# 8                    108   8.2
# 9                    180   7.5
# 3                    175   8.1
# 2                    969   8.1
# 0                    423   6.9

# %%
df2.sort_index()
# Out:
#                 Actor                   Film  Year             Genre  \
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
# 1          Aamir Khan                 Dangal  2016      Sports-Drama
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy
#
#    BoxOffice (INR Crore)  IMDB
# 0                    423   6.9
# 1                   2024   8.4
# 2                    969   8.1
# 3                    175   8.1
# 4                    456   8.2
# 5                    585   7.0
# 6                    197   7.7
# 7                    311   7.2
# 8                    108   8.2
# 9                    180   7.5

# %%
df2["Rank"]=df2["IMDB"]

# %%
df2
# Out:
#                 Actor                   Film  Year             Genre  \
# 1          Aamir Khan                 Dangal  2016      Sports-Drama
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
#
#    BoxOffice (INR Crore)  IMDB  Rank
# 1                   2024   8.4   8.4
# 7                    311   7.2   7.2
# 6                    197   7.7   7.7
# 4                    456   8.2   8.2
# 5                    585   7.0   7.0
# 8                    108   8.2   8.2
# 9                    180   7.5   7.5
# 3                    175   8.1   8.1
# 2                    969   8.1   8.1
# 0                    423   6.9   6.9

# %%
df2["rank"]=df2["IMDB"].rank(ascending=False,method="dense")

# %%
df2
# Out:
#                 Actor                   Film  Year             Genre  \
# 1          Aamir Khan                 Dangal  2016      Sports-Drama
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
#
#    BoxOffice (INR Crore)  IMDB  Rank  rank
# 1                   2024   8.4   8.4   1.0
# 7                    311   7.2   7.2   8.0
# 6                    197   7.7   7.7   6.0
# 4                    456   8.2   8.2   2.5
# 5                    585   7.0   7.0   9.0
# 8                    108   8.2   8.2   2.5
# 9                    180   7.5   7.5   7.0
# 3                    175   8.1   8.1   4.5
# 2                    969   8.1   8.1   4.5
# 0                    423   6.9   6.9  10.0

# %%
df.rename(columns={"Actor":"Actors"},inplace=True)

# %%
df
# Out:
#                Actors                   Film  Year             Genre  \
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy
# 1          Aamir Khan                 Dangal  2016      Sports-Drama
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy
#
#    BoxOffice (INR Crore)  IMDB
# 0                    423   6.9
# 1                   2024   8.4
# 2                    969   8.1
# 3                    175   8.1
# 4                    456   8.2
# 5                    585   7.0
# 6                    197   7.7
# 7                    311   7.2
# 8                    108   8.2
# 9                    180   7.5

# %%
df=df[["Actors","Film","Year","Genre","IMDB","BoxOffice (INR Crore)"]]##reorder

# %%
df
# Out:
#                Actors                   Film  Year             Genre  IMDB  \
# 0      Shah Rukh Khan        Chennai Express  2013     Action-Comedy   6.9
# 1          Aamir Khan                 Dangal  2016      Sports-Drama   8.4
# 2         Salman Khan      Bajrangi Bhaijaan  2015             Drama   8.1
# 3       Ranbir Kapoor                 Barfi!  2012   Romantic-Comedy   8.1
# 4  Ayushmann Khurrana              Andhadhun  2018          Thriller   8.2
# 5    Deepika Padukone              Padmaavat  2018  Historical-Drama   7.0
# 6          Alia Bhatt                  Raazi  2018      Spy-Thriller   7.7
# 7        Akshay Kumar  Toilet: Ek Prem Katha  2017      Comedy-Drama   7.2
# 8      Kangana Ranaut                  Queen  2014      Comedy-Drama   8.2
# 9       Rajkummar Rao                  Stree  2018     Horror-Comedy   7.5
#
#    BoxOffice (INR Crore)
# 0                    423
# 1                   2024
# 2                    969
# 3                    175
# 4                    456
# 5                    585
# 6                    197
# 7                    311
# 8                    108
# 9                    180

# %%
cols = ["Year"] + [col for col in df.columns if col != "Year"]
df = df[cols]

# %%
df
# Out:
#    Year              Actors                   Film             Genre  IMDB  \
# 0  2013      Shah Rukh Khan        Chennai Express     Action-Comedy   6.9
# 1  2016          Aamir Khan                 Dangal      Sports-Drama   8.4
# 2  2015         Salman Khan      Bajrangi Bhaijaan             Drama   8.1
# 3  2012       Ranbir Kapoor                 Barfi!   Romantic-Comedy   8.1
# 4  2018  Ayushmann Khurrana              Andhadhun          Thriller   8.2
# 5  2018    Deepika Padukone              Padmaavat  Historical-Drama   7.0
# 6  2018          Alia Bhatt                  Raazi      Spy-Thriller   7.7
# 7  2017        Akshay Kumar  Toilet: Ek Prem Katha      Comedy-Drama   7.2
# 8  2014      Kangana Ranaut                  Queen      Comedy-Drama   8.2
# 9  2018       Rajkummar Rao                  Stree     Horror-Comedy   7.5
#
#    BoxOffice (INR Crore)
# 0                    423
# 1                   2024
# 2                    969
# 3                    175
# 4                    456
# 5                    585
# 6                    197
# 7                    311
# 8                    108
# 9                    180
